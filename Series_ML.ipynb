# %%
import numpy as np
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %% [markdown]
# # Importar Serie em xls
#
# O preço do Brent pode ser encontrado no site da eia (Preço FOB) - no futuro a importação será automatizada

# %%
serie=pd.read_excel('RBRTEd.xls', sheetname="Data 1", index_col=0, header=2)

# %%
serie.head()
# Out:
#             Europe Brent Spot Price FOB (Dollars per Barrel)
# Date
# 1987-05-20                                             18.63
# 1987-05-21                                             18.45
# 1987-05-22                                             18.55
# 1987-05-25                                             18.60
# 1987-05-26                                             18.63

# %% [markdown]
# ## Alterando denominação da coluna e convertendo index em data

# %%
serie.columns
# Out:
# Index(['Europe Brent Spot Price FOB (Dollars per Barrel)'], dtype='object')

# %%
serie.columns=['Brent']

# %%
serie.columns
# Out:
# Index(['Brent'], dtype='object')

# %%
serie.index=pd.to_datetime(serie.index)

# %%
serie.head()
# Out:
#             Brent
# Date
# 1987-05-20  18.63
# 1987-05-21  18.45
# 1987-05-22  18.55
# 1987-05-25  18.60
# 1987-05-26  18.63

# %% [markdown]
# # Gerando Gráficos do dado Bruto

# %% [markdown]
# ### Série Completa

# %%
serie.plot()

# %% [markdown]
# ### Gráficos de 4 anos da série

# %%
serie["2008":"2011"].plot()

# %%
serie["2015-04":"2019-04"].plot()

# %% [markdown]
# #### Verificação dos limtes e Tamanho

# %%
serie["2015-04":"2019-04"].index[0]
serie["2015-04":"2019-04"].index[-1]
# Out:
# Timestamp('2019-04-30 00:00:00')

# %%
# ano de 250 dias
len(serie["2015-04":"2019-04"])/250
# Out:
# 4.156

# %% [markdown]
# # Gerando Gráficos de Tudo associado a Óleo Cru

# %%
serie_1=pd.read_excel('PET_PRI_SPT_S1_D.xls', sheetname="Data 1", index_col=0, header=2)

# %%
serie_1.head()
# Out:
#             Cushing, OK WTI Spot Price FOB (Dollars per Barrel)  \
# Date
# 1986-01-02                                              25.56
# 1986-01-03                                              26.00
# 1986-01-06                                              26.53
# 1986-01-07                                              25.85
# 1986-01-08                                              25.87
#
#             Europe Brent Spot Price FOB (Dollars per Barrel)
# Date
# 1986-01-02                                               NaN
# 1986-01-03                                               NaN
# 1986-01-06                                               NaN
# 1986-01-07                                               NaN
# 1986-01-08                                               NaN

# %%
serie_1.plot()

# %%
for i in range(7):
    globals()['serie_{}'.format(i+1)] = pd.read_excel('PET_PRI_SPT_S1_D.xls', sheetname='Data {}'.format(i+1), index_col=0, header=2)

# %%
serie_x=pd.concat([serie_1,serie_2,serie_3,serie_4,serie_5,serie_6,serie_7])

# %%
serie_x.columns
# Out:
# Index(['Cushing, OK WTI Spot Price FOB (Dollars per Barrel)',
#        'Europe Brent Spot Price FOB (Dollars per Barrel)',
#        'Los Angeles Reformulated RBOB Regular Gasoline Spot Price (Dollars per Gallon)',
#        'Los Angeles, CA Ultra-Low Sulfur CARB Diesel Spot Price (Dollars per Gallon)',
#        'Mont Belvieu, TX Propane Spot Price FOB (Dollars per Gallon)',
#        'New York Harbor Conventional Gasoline Regular Spot Price FOB (Dollars per Gallon)',
#        'New York Harbor No. 2 Heating Oil Spot Price FOB (Dollars per Gallon)',
#        'New York Harbor Ultra-Low Sulfur No 2 Diesel Spot Price (Dollars per Gallon)',
#        'U.S. Gulf Coast Conventional Gasoline Regular Spot Price FOB (Dollars per Gallon)',
#        'U.S. Gulf Coast Kerosene-Type Jet Fuel Spot Price FOB (Dollars per Gallon)',
#        'U.S. Gulf Coast Ultra-Low Sulfur No 2 Diesel Spot Price (Dollars per Gallon)'],
#       dtype='object')

# %%
serie_x.columns=['WTI_FOB','Brent_FOB','Gasoline_LA',"ULS_Diesel_LA",'TX_Propane_MB','Gasoline_NY','Heating_Oil_NY',"ULS_Diesel_NY","Gasoline_Gulf","Kerosene_Gulf","ULS_Diesel_Gulf"]

# %%
serie_x.columns
# Out:
# Index(['WTI_FOB', 'Brent_FOB', 'Gasoline_LA', 'ULS_Diesel_LA', 'TX_Propane_MB',
#        'Gasoline_NY', 'Heating_Oil_NY', 'ULS_Diesel_NY', 'Gasoline_Gulf',
#        'Kerosene_Gulf', 'ULS_Diesel_Gulf'],
#       dtype='object')

# %%
serie_x.plot(subplots=True, figsize=(10,20),grid=True,linestyle='--' ); 
#plt.legend(loc='best')

# %%
serie_x.Gasoline_Gulf.plot.hist(bins=70)

# %%
#serie_x.WTI_FOB.plot.hist(bins=70)
serie_x.Gasoline_NY.plot.hist(bins=70)

# %%
fig, axes= plt.pyplot.subplots(nrows=2,ncols=2)
serie_x.Brent_FOB.plot(ax=axes[0,0]);
plt.legend(loc="best")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-ce59b2a0a8f4> in <module>()
#       1 fig, axes= plt.pyplot.subplots(nrows=2,ncols=2)
#       2 serie_x.Brent_FOB.plot(ax=axes[0,0]);
# ----> 3 plt.legend(loc="best")
#
# TypeError: 'module' object is not callable

# %%
fig, ax= plt.pyplot.subplot(4,4, figsize=(10,5))
serie_x.index.plot(ax=axs[0])
serie_x.plot(ax=axs[1])
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

In [36]: df['A'].plot(ax=axes[0,0]); axes[0,0].set_title('A')
Out[36]: <matplotlib.text.Text at 0x148f5c90>

In [37]: df['B'].plot(ax=axes[0,1]); axes[0,1].set_title('B')
Out[37]: <matplotlib.text.Text at 0x98ec550>

In [38]: df['C'].plot(ax=axes[1,0]); axes[1,0].set_title('C')
Out[38]: <matplotlib.text.Text at 0x146b6e90>

In [39]: df['D'].plot(ax=axes[1,1]); axes[1,1].set_title('D')
Out[39]: <matplotlib.text.Text at 0x146cb690>
